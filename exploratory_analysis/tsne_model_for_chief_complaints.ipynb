# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.manifold import TSNE


# load the dataset by pickle
df = ##

# %%
df_labels = pd.read_csv('../code/temp_data_v2/before_model.csv')

# %%
df_labels['index'] = df_labels.index

# %%
from sklearn.manifold import TSNE

df_tsne_2d = TSNE(
                  n_components=2, 
                  learning_rate=500, 
                  init='random', 
                  perplexity=200, 
                  n_iter = 5000).fit_transform(sample.iloc[:,:-2])

# %%
df_tsne_2d_pd = pd.concat([pd.DataFrame(df_tsne_2d),sample[['TRIAJ_New','Şikayeti_agg']]],axis=1)

# %%
df_tsne_2d_pd.columns = ['comp1','comp2','TRIAJ_New','Şikayeti_agg']

# %%
df_tsne_2d_pd_sample = df_tsne_2d_pd.sample(100).reset_index(drop=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Plotting
plt.figure(figsize=(50, 50))
sns.scatterplot(data=df_tsne_2d_pd_sample, x='comp1', y='comp2', hue='TRIAJ_New', palette='viridis', legend="full")

# Annotating each point with the chief complaint text
for i in range(df_tsne_2d_pd_sample.shape[0]):
    plt.text(df_tsne_2d_pd_sample['comp1'][i], df_tsne_2d_pd_sample['comp2'][i], df_tsne_2d_pd_sample['Şikayeti_agg'][i], horizontalalignment='left', size='medium', color='black', weight='semibold')

plt.title("Scatter Plot with Chief Complaints and TRIAJ")
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.grid(True)
plt.show()
